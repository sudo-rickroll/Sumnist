# %% [markdown]
# # Mounting Google Drive to import the project packages

# %%
from google.colab import drive
drive.mount('GDrive')
# Out:
# Drive already mounted at GDrive; to attempt to forcibly remount, call drive.mount("GDrive", force_remount=True).

# %% [markdown]
# # Changing the directory to the drive folder where the packages are located

# %%
# %cd '/content/GDrive/MyDrive/END2_S3'
# Out:
# /content/GDrive/MyDrive/END2_S3

# %% [markdown]
# # Configuration changes to plot the matplotlib graphs inside the notebook and to ignore warnings

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Running the model on the Train Dataset and displaying the corresponding statistics

# %%
# %run main.py --mode 'Train' --checkpoint_save './checkpoint/mnist_sum.pth'
# Out:
# Training the model...
#
# Epoch 1 :
#
# Training stats :
# Accuracy MNIST=  92.57
# Accuracy Total=  17.35
# Loss MNIST=  174.14468090
# Loss Total=  1579.59326267
#
# Validation stats :
# Accuracy MNIST=  97.49
# Accuracy Total=  29.54
# Loss MNIST=  8.76225397
# Loss Total=  200.64110672
# ------------------------
#
# Epoch 2 :
#
# Training stats :
# Accuracy MNIST=  98.34
# Accuracy Total=  36.94
# Loss MNIST=  35.21386456
# Loss Total=  1034.63542533
#
# Validation stats :
# Accuracy MNIST=  98.38
# Accuracy Total=  46.19
# Loss MNIST=  5.32540390
# Loss Total=  153.89136648
# ------------------------
#
# Epoch 3 :
#
# Training stats :
# Accuracy MNIST=  98.82
# Accuracy Total=  48.08
# Loss MNIST=  24.93488859
# Loss Total=  846.02957535
#
# Validation stats :
# Accuracy MNIST=  98.71
# Accuracy Total=  54.33
# Loss MNIST=  4.17927438
# Loss Total=  132.31201744
# ------------------------
#
# Epoch 4 :
#
# Training stats :
# Accuracy MNIST=  99.09
# Accuracy Total=  54.63
# ...

# %% [markdown]
# # Running the model on the Test Dataset and displaying the corresponding statistics

# %%
# %run main.py --mode 'Validate' --checkpoint_load './checkpoint/mnist_sum.pth'
# Out:
# Loading model checkpoint from './checkpoint/mnist_sum.pth'
# Model loaded successfully
#
# Validating the model...
#
# Sample of validation :
# Image stored in the 'images' folder
#
# Validation stats :
# Accuracy MNIST=  99.11
# Accuracy Total=  74.35
# Loss MNIST=  2.64079529
# Loss Total=  83.91607481
# ------------------------
